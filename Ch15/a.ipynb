# %% [markdown]
# # 15-1 語音轉文字（Speech-to-Text）

# %%
import speech_recognition as sr

def bot_listen():
    recog = sr.Recognizer()
    with sr.Microphone() as source:
        audioData = recog.listen(source)
    try:
        text = recog.recognize_google(audioData, language = "zh-tw")
        return text
    except:
        return "聽不懂"
    
question = bot_listen()
print(question)
# Out:
# 天氣之子

# %% [markdown]
# # 15-2 文字轉語音（Text-to-Speech）

# %%
from gtts import lang

lang.tts_langs()
# Out:
# {'af': 'Afrikaans',
#  'ar': 'Arabic',
#  'bg': 'Bulgarian',
#  'bn': 'Bengali',
#  'bs': 'Bosnian',
#  'ca': 'Catalan',
#  'cs': 'Czech',
#  'da': 'Danish',
#  'de': 'German',
#  'el': 'Greek',
#  'en': 'English',
#  'es': 'Spanish',
#  'et': 'Estonian',
#  'fi': 'Finnish',
#  'fr': 'French',
#  'gu': 'Gujarati',
#  'hi': 'Hindi',
#  'hr': 'Croatian',
#  'hu': 'Hungarian',
#  'id': 'Indonesian',
#  'is': 'Icelandic',
#  'it': 'Italian',
#  'iw': 'Hebrew',
#  'ja': 'Japanese',
#  'jw': 'Javanese',
#  'km': 'Khmer',
#  'kn': 'Kannada',
#  'ko': 'Korean',
#  'la': 'Latin',
#  'lv': 'Latvian',
#  'ml': 'Malayalam',
#  'mr': 'Marathi',
#  'ms': 'Malay',
#  'my': 'Myanmar (Burmese)',
#  'ne': 'Nepali',
#  'nl': 'Dutch',
#  'no': 'Norwegian',
#  'pl': 'Polish',
#  'pt': 'Portuguese',
#  'ro': 'Romanian',
#  'ru': 'Russian',
#  'si': 'Sinhala',
#  'sk': 'Slovak',
#  'sq': 'Albanian',
#  'sr': 'Serbian',
#  'su': 'Sundanese',
#  'sv': 'Swedish',
#  'sw': 'Swahili',
#  'ta': 'Tamil',
# ...

# %%
from gtts import gTTS

tts = gTTS(text = "我是萱萱", lang = "zh-tw")
tts.save("我是萱萱的語音檔.mp3")

# %% [markdown]
# # 15-3 播放聲音

# %%
from pygame import mixer
from gtts import gTTS

# tts = gTTS(text = "我是萱萱", lang = "zh-tw")
# tts.save("我是萱萱的語音檔.mp3")

mixer.init()
mixer.music.load("我是萱萱的語音檔.mp3")
mixer.music.play()

# %%
import os
from gtts import gTTS

if not os.path.isfile("tmp.mp3"):
    tts = gTTS(text = "不重要的語音檔", lang = "zh-tw")
    tts.save("tmp.mp3")
    print("已產生不重要的語音檔 tmp.mp3")
# Out:
# 已產生不重要的語音檔 tmp.mp3

# %%
import os
from pygame import mixer
from gtts import gTTS

mixer.init()
if not os.path.isfile("tmp.mp3"):
    tts = gTTS(text = "不重要的語音檔", lang = "zh-tw")
    tts.save("tmp.mp3")
    print("已產生不重要的語音檔 tmp.mp3")
#-----------------------#
def bot_speak(text, lang):
    try:
        mixer.music.load("tmp.mp3")
        tts = gTTS(text = text, lang = lang)
        tts.save("speak.mp3")
        mixer.music.load("speak.mp3")
        mixer.music.play()
        while (mixer.music.get_busy()):
            continue
    except:
        print("播放音效失敗")
#-----------------------#
bot_speak("我是萱萱", "zh-tw")

# %% [markdown]
# # 15-4 取得網頁原始碼

# %%
import requests

response = requests.get("https://zh.wikipedia.org/zh-tw/愛因斯坦")
if response.status_code == 200:
    print(response.text)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-client-prefs-pinned-disabled vector-feature-night-mode-disabled skin-night-mode-clientpref-0 vector-toc-available" lang="zh-Hant-TW" dir="ltr">
# <head>
# <meta charset="UTF-8">
# <title>阿爾伯特·愛因斯坦 - 維基百科，自由的百科全書</title>
# ...

# %% [markdown]
# # 15-5 解析網頁原始碼

# %%
from bs4 import BeautifulSoup as bs
import requests

def bot_get_wiki(keyword):
    response = requests.get("https://zh.wikipedia.org/zh-tw/" + keyword)
    soup = bs(response.text, features = "lxml")

    p_list = soup.find_all("p")
    # print(p_list)
    for p in p_list:
        # print(p.text)
        # print("-----")
        if keyword in p.text[0: 10]:
            return p.text

sentence = bot_get_wiki("愛因斯坦")
sentence
# Out:
# '阿爾伯特·愛因斯坦（德語：Albert Einstein／ˈalbɛʁt ˈʔaɪnʃtaɪnⓘ，1879年3月14日—1955年4月18日），是出生於德國、擁有瑞士和美國國籍的猶太裔理論物理學家，他創立了現代物理學的兩大支柱的相對論及量子力學[36]:274[1]，也是質能等價公式（E = mc2）的發現者[37]。他在科學哲學領域頗具影響力[38][39]。因為「對理論物理的貢獻，特別是發現了光電效應的原理」，他榮獲1921年度的諾貝爾物理學獎（1922年頒發）。這一發現為量子理論的建立踏出了關鍵性的一步。[40]\n'

# %% [markdown]
# # 15-6 文章的優化

# %%
bot_speak(sentence, lang = "zh-tw")

# %%
sentence
# Out:
# '阿爾伯特·愛因斯坦（德語：Albert Einstein／ˈalbɛʁt ˈʔaɪnʃtaɪnⓘ，1879年3月14日—1955年4月18日），是出生於德國、擁有瑞士和美國國籍的猶太裔理論物理學家，他創立了現代物理學的兩大支柱的相對論及量子力學[36]:274[1]，也是質能等價公式（E = mc2）的發現者[37]。他在科學哲學領域頗具影響力[38][39]。因為「對理論物理的貢獻，特別是發現了光電效應的原理」，他榮獲1921年度的諾貝爾物理學獎（1922年頒發）。這一發現為量子理論的建立踏出了關鍵性的一步。[40]\n'

# %%
import re
print(re.findall(r"\[[^\]]*\]", sentence))
re.findall(r"\[.*?\]", sentence)
# Out:
# ['[36]', '[1]', '[37]', '[38]', '[39]', '[40]']
# ['[36]', '[1]', '[37]', '[38]', '[39]', '[40]']

# %%
import re
# test = re.findall(r"／.*?ⓘ", sentence)
test = re.sub(r"／.*?ⓘ", "", sentence)
test
# Out:
# '阿爾伯特·愛因斯坦（德語：Albert Einstein，1879年3月14日—1955年4月18日），是出生於德國、擁有瑞士和美國國籍的猶太裔理論物理學家，他創立了現代物理學的兩大支柱的相對論及量子力學[36]:274[1]，也是質能等價公式（E = mc2）的發現者[37]。他在科學哲學領域頗具影響力[38][39]。因為「對理論物理的貢獻，特別是發現了光電效應的原理」，他榮獲1921年度的諾貝爾物理學獎（1922年頒發）。這一發現為量子理論的建立踏出了關鍵性的一步。[40]\n'

# %%
import re

sentence = "阿爾伯特·愛因斯坦（德語：Albert Einstein／ˈalbɛʁt ˈʔaɪnʃtaɪnⓘ，1879年3月14日—1955年4月18日），是出生於德國、擁有瑞士和美國國籍的猶太裔理論物理學家，他創立了現代物理學的兩大支柱的相對論及量子力學[36]:274[1]，也是質能等價公式（E = mc2）的發現者[37]。"
s1 = re.sub(r"\[[^\]]*\]", "", sentence) # 用*和+是一樣的結果
s1 = re.sub(r"／.*?ⓘ", "", s1)
print(s1)
# Out:
# 阿爾伯特·愛因斯坦（德語：Albert Einstein，1879年3月14日—1955年4月18日），是出生於德國、擁有瑞士和美國國籍的猶太裔理論物理學家，他創立了現代物理學的兩大支柱的相對論及量子力學:274，也是質能等價公式（E = mc2）的發現者。

# %%
en_list = re.findall(r"[a-zA-Z ]+", s1) # 用+才不會有""
en_list
# Out:
# ['Albert Einstein', 'E ', ' mc']

# %%
s2 = re.sub(r"[a-zA-Z \-]+", "@English@", s1) # 有沒有\-是一樣的
s2
# Out:
# '阿爾伯特·愛因斯坦（德語：@English@，1879年3月14日—1955年4月18日），是出生於德國、擁有瑞士和美國國籍的猶太裔理論物理學家，他創立了現代物理學的兩大支柱的相對論及量子力學:274，也是質能等價公式（@English@=@English@2）的發現者。'

# %%
all_list = s2.split("@")
print(all_list)
# Out:
# ['阿爾伯特·愛因斯坦（德語：', 'English', '，1879年3月14日—1955年4月18日），是出生於德國、擁有瑞士和美國國籍的猶太裔理論物理學家，他創立了現代物理學的兩大支柱的相對論及量子力學:274，也是質能等價公式（', 'English', '=', 'English', '2）的發現者。']

# %%
import re
from gtts import gTTS
from pygame import mixer
import os

mixer.init()
if not os.path.isfile("tmp.mp3"):
    tts = gTTS(text = "不重要的語音檔", lang = "zh-tw")
    tts.save("tmp.mp3")
    print("已產生不重要的語音檔 tmp.mp3")
def bot_speak(text, lang):
    try:
        mixer.music.load("tmp.mp3")
        tts = gTTS(text = text, lang = lang)
        tts.save("speak.mp3")
        mixer.music.load("speak.mp3")
        mixer.music.play()
        while (mixer.music.get_busy()):
            continue
    except:
        print("播放音效失敗")

def bot_speak_re(sentence):
    s1 = re.sub(r"\[[^\]]*\]", "", sentence)
    s1 = re.sub(r"／.*?ⓘ", "", s1)
    print(s1)
    en_list = re.findall(r"[a-zA-Z ]+", s1)
    s2 = re.sub(r"[a-zA-Z \-]+", "@English@", s1)
    all_list = s2.split("@")
    index = 0
    for text in all_list:
        if text != "English":
            bot_speak(text, "zh-tw")
        else:
            bot_speak(en_list[index], "en")
            index += 1

sentence = "阿爾伯特·愛因斯坦（德語：Albert Einstein／ˈalbɛʁt ˈʔaɪnʃtaɪnⓘ，1879年3月14日—1955年4月18日），是出生於德國、擁有瑞士和美國國籍的猶太裔理論物理學家，他創立了現代物理學的兩大支柱的相對論及量子力學[36]:274[1]，也是質能等價公式（E = mc2）的發現者[37]。他在科學哲學領域頗具影響力[38][39]。因為「對理論物理的貢獻，特別是發現了光電效應的原理」，他榮獲1921年度的諾貝爾物理學獎（1922年頒發）。這一發現為量子理論的建立踏出了關鍵性的一步。[40]\n"
bot_speak_re(sentence)
# Out:
# 阿爾伯特·愛因斯坦（德語：Albert Einstein，1879年3月14日—1955年4月18日），是出生於德國、擁有瑞士和美國國籍的猶太裔理論物理學家，他創立了現代物理學的兩大支柱的相對論及量子力學:274，也是質能等價公式（E = mc2）的發現者。他在科學哲學領域頗具影響力。因為「對理論物理的貢獻，特別是發現了光電效應的原理」，他榮獲1921年度的諾貝爾物理學獎（1922年頒發）。這一發現為量子理論的建立踏出了關鍵性的一步。

# %% [markdown]
# # 15-7 語意分析

# %%
import requests
from bs4 import BeautifulSoup as bs
from hanziconv import HanziConv

def bot_get_google(question):
    url = f"https://www.google.com/search?q={question}+維基百科"
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"}
    response = requests.get(url, headers = headers)
    if response.status_code == 200:
        soup = bs(response.text, features = "lxml")
        # print(soup.find_all("cite"))
        # return soup
        wiki_url = soup.find("cite")
        kwd = wiki_url.text.split("›")[-1].strip()
        kwd_tra = HanziConv.toTraditional(kwd)
        return kwd_tra

#---------------#
keyword = bot_get_google("誰是愛因斯坦")
print(keyword)
# Out:
# 漢斯·愛因斯坦

# %%
kwd = keyword.find("cite").text.split("›")[-1].strip()
kwd_tra = HanziConv.toTraditional(kwd)
kwd_tra
# Out:
# '漢斯·愛因斯坦'

# %% [markdown]
# # 15-8 實戰：語音聊天機器人

# %%
import chatBot_module as m

# question = ""
answer = ""
QA = {"你是誰": "我是萱萱", "聽不懂": "請再說一次問題"}

question = m.bot_listen()
print(question)

if question in QA:
    answer = QA[question]
    print(answer)
    m.bot_speak(answer, lang = "zh-tw")
else:
    print("進行網路爬蟲")
# Out:
# 你是誰
# 我是萱萱

# %%
import chatBot_module as m

question = ""
answer = ""
QA = {"你是誰": "我是萱萱", "聽不懂": "請再說一次問題"}
question = m.bot_listen()
print(question)
if question in QA:
    answer = QA[question]
    print(answer)
    m.bot_speak(answer, lang = "zh-tw")
else:
    keyword = m.bot_get_google(question)
    # print(keyword)
    content = m.bot_get_wiki(keyword)
    if content != None:
        m.bot_speak_re(content)
    else:
        print("找不到相關的維基百科資料")
# Out:
# 紅髮艾德
# 紅髮艾德也是少數擁有西蘭公國男爵爵位的英國人。
