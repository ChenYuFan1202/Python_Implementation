# %% [markdown]
# # 12-4 實戰：無人車系統，交通標誌辨識

# %%
import cv2

img = cv2.imread("pic_turnR.jpg")
detector = cv2.CascadeClassifier("haar_turnR.xml")
signs = detector.detectMultiScale(img, minSize = (30, 30), scaleFactor = 1.1, minNeighbors = 2)

if len(signs) > 0:
    for (x, y, w, h) in signs:
        cv2.rectangle(img, (x, y), (x + w, y + h), (0, 0, 255), 2)
else:
    print("nothing")
    
cv2.imshow("Frame", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img.shape
# Out:
# (480, 640, 3)

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread("pic_turnR.jpg")
plt.imshow(img)
plt.show()
